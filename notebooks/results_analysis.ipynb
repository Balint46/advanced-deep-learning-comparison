# %% [markdown]
# # Results Analysis
#
# Load experiment outputs and regenerate the presentation plots.

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
summary = pd.read_csv(project_root / 'results' / 'summary_table.csv')
metrics = pd.read_csv(project_root / 'results' / 'metrics.csv')
summary.head()

# %%
summary.sort_values('top1_accuracy', ascending=False).head(10)

# %%
import sys
sys.path.append(str(project_root))
from src.plots import generate_all_plots

generate_all_plots()
print('Plots regenerated in results/plots/')
